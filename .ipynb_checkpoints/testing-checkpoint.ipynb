# %%
from automation import automation

# %%
automation()
# Out:
# Automation
# 1. Calculate total sales
# 2. Calculate Salary
# 3. Calculate Profit or Loss
# 4. Calculate Tip for a shift
# 5. Calculate total Tips for a the day
# 6. Exit Program
# Enter your choice from (1-6): 4
# Please calculate total sales (option 1) before calculating tip for a shift.
#
# Automation
# 1. Calculate total sales
# 2. Calculate Salary
# 3. Calculate Profit or Loss
# 4. Calculate Tip for a shift
# 5. Calculate total Tips for a the day
# 6. Exit Program
# Enter your choice from (1-6): 4
# Please calculate total sales (option 1) before calculating tip for a shift.
#
# Automation
# 1. Calculate total sales
# 2. Calculate Salary
# 3. Calculate Profit or Loss
# 4. Calculate Tip for a shift
# 5. Calculate total Tips for a the day
# 6. Exit Program
# Enter your choice from (1-6): 4
# Please calculate total sales (option 1) before calculating tip for a shift.
#
# Automation
# 1. Calculate total sales
# 2. Calculate Salary
# 3. Calculate Profit or Loss
# ...
